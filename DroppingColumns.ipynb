# %%
import pandas as pd
df = pd.read_csv("/Users/suso/BootcampDA/MiniProject/data_mid_bootcamp_project_FIFA_MoneyBall/fifa21_male2.csv")
# Out:
# /var/folders/5y/_5l3y2p900scjg2bd7r52_lh0000gn/T/ipykernel_6471/4033839146.py:2: DtypeWarning: Columns (78) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/Users/suso/BootcampDA/MiniProject/data_mid_bootcamp_project_FIFA_MoneyBall/fifa21_male2.csv")

# %%
df.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                       Player Photo  ...  \
# 0            LM  https://cdn.sofifa.com/players/000/002/16_120.png  ...
# 1    CM CAM CDM  https://cdn.sofifa.com/players/000/016/19_120.png  ...
# 2  CAM RM RW LM  https://cdn.sofifa.com/players/000/027/16_120.png  ...
# 3           NaN  https://cdn.sofifa.com/players/000/036/09_120.png  ...
# 4        CM CAM  https://cdn.sofifa.com/players/000/041/20_120.png  ...
#
#      CDM    RDM    RWB     LB   LCB    CB   RCB     RB    GK Gender
# ...

# %%
# I start dropping insignificant columns, such as those which tell the overall a player can have when playing a different position.
df.drop(['Player Photo', 'CDM', 'RDM', 'RWB', 'LB', 'LCB', 'CB', 'RCB', 'RB', 'GK'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                                         Club Logo  ...    CAM  \
# 0            LM      https://cdn.sofifa.com/teams/55/light_60.png  ...   68+0
# 1    CM CAM CDM    https://cdn.sofifa.com/teams/2013/light_60.png  ...   70+1
# 2  CAM RM RW LM    https://cdn.sofifa.com/teams/1800/light_60.png  ...   71+0
# 3           NaN     https://cdn.sofifa.com/teams/106/light_60.png  ...   70+0
# 4        CM CAM  https://cdn.sofifa.com/teams/101146/light_60.png  ...  82+-1
#
# ...

# %%
df.drop(['Club Logo', 'CAM', 'RAM', 'LM', 'LCM', 'CM', 'RCM', 'RM', 'LWB', 'LDM'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position                               Flag Photo  ...    LS    ST  \
# 0            LM      https://cdn.sofifa.com/flags/it.png  ...  65+0  65+0
# 1    CM CAM CDM      https://cdn.sofifa.com/flags/es.png  ...  67+1  67+1
# 2  CAM RM RW LM  https://cdn.sofifa.com/flags/gb-eng.png  ...  64+0  64+0
# 3           NaN      https://cdn.sofifa.com/flags/tt.png  ...  67+0  67+0
# 4        CM CAM      https://cdn.sofifa.com/flags/es.png  ...  72+3  72+3
#
#      RS    LW    LF    CF    RF    RW    LAM Gender
# ...

# %%
df.drop(['Flag Photo', 'LS', 'ST', 'RS', 'LW', 'LF', 'CF', 'RF', 'RW', 'LAM'], axis=1, inplace=True)

# %%
df.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club  BOV   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese   71  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   70   CM
# 2  27      J. Cole   33   71                England  Coventry City   71  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   70   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe   82  CAM
#
#        Position  POT  ...     D/W   IR PAC SHO  PAS DRI DEF PHY Hits Gender
# 0            LM   69  ...    High  2 ★  71  59   70  71  68  69    4   Male
# 1    CM CAM CDM   71  ...  Medium  1 ★  53  69   73  69  58  63    4   Male
# 2  CAM RM RW LM   71  ...     Low  2 ★  45  68   76  77  36  52   11   Male
# 3           NaN   82  ...     NaN  1 ★  61  66   66  69  47  60    3   Male
# 4        CM CAM   81  ...  Medium  4 ★  58  70   85  85  63  59  149   Male
#
# [5 rows x 77 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP',
#        'Position', 'POT', 'Team & Contract', 'Height', 'Weight', 'foot',
#        'Growth', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause',
#        'Contract', 'Attacking', 'Crossing', 'Finishing', 'Heading Accuracy',
#        'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve',
#        'FK Accuracy', 'Long Passing', 'Ball Control', 'Movement',
#        'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance',
#        'Power', 'Shot Power', 'Jumping', 'Stamina', 'Strength', 'Long Shots',
#        'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision',
#        'Penalties', 'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
# ...

# %%
#In the following lines I drop columns describing the main stats (PAC, SHO, PAS, DRI, DEF, PHY). I will only leave this main stats columns.
df.drop(['Attacking', 'Crossing', 'Finishing', 'Heading Accuracy', 'Short Passing', 'Volleys', 'Skill', 'Dribbling', 'Curve', 'FK Accuracy'], axis=1, inplace=True)

# %%
df.drop(['Long Passing', 'Ball Control', 'Movement', 'Acceleration', 'Sprint Speed', 'Agility', 'Reactions', 'Balance', 'Power', 'Shot Power'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP',
#        'Position', 'POT', 'Team & Contract', 'Height', 'Weight', 'foot',
#        'Growth', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause',
#        'Contract', 'Jumping', 'Stamina', 'Strength', 'Long Shots', 'Mentality',
#        'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties',
#        'Composure', 'Defending', 'Marking', 'Standing Tackle',
#        'Sliding Tackle', 'Goalkeeping', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Total Stats',
#        'Base Stats', 'W/F', 'SM', 'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Hits', 'Gender'],
#       dtype='object')

# %%
df.drop(['Jumping', 'Stamina', 'Strength', 'Long Shots', 'Mentality', 'Aggression', 'Interceptions', 'Positioning', 'Vision', 'Penalties'], axis=1, inplace=True)

# %%
df.drop(['Composure', 'Defending', 'Marking', 'Standing Tackle', 'Sliding Tackle', 'GK Diving', 'GK Handling', 'GK Kicking', 'GK Positioning', 'GK Reflexes'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BOV', 'BP',
#        'Position', 'POT', 'Team & Contract', 'Height', 'Weight', 'foot',
#        'Growth', 'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause',
#        'Contract', 'Goalkeeping', 'Total Stats', 'Base Stats', 'W/F', 'SM',
#        'A/W', 'D/W', 'IR', 'PAC', 'SHO', 'PAS', 'DRI', 'DEF', 'PHY', 'Hits',
#        'Gender'],
#       dtype='object')

# %%
df.drop(['W/F', 'SM', 'A/W', 'D/W', 'Hits', 'BOV', 'Goalkeeping'], axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['ID', 'Name', 'Age', 'OVA', 'Nationality', 'Club', 'BP', 'Position',
#        'POT', 'Team & Contract', 'Height', 'Weight', 'foot', 'Growth',
#        'Joined', 'Loan Date End', 'Value', 'Wage', 'Release Clause',
#        'Contract', 'Total Stats', 'Base Stats', 'IR', 'PAC', 'SHO', 'PAS',
#        'DRI', 'DEF', 'PHY', 'Gender'],
#       dtype='object')

# %%
df.head()
# Out:
#    ID         Name  Age  OVA            Nationality           Club   BP  \
# 0   2  G. Pasquale   33   69                  Italy        Udinese  LWB
# 1  16  Luis García   37   71                  Spain      KAS Eupen   CM
# 2  27      J. Cole   33   71                England  Coventry City  CAM
# 3  36     D. Yorke   36   68  Trinidad &amp; Tobago     Sunderland   ST
# 4  41      Iniesta   36   81                  Spain    Vissel Kobe  CAM
#
#        Position  POT            Team & Contract  ... Total Stats Base Stats  \
# 0            LM   69        Udinese 2008 ~ 2016  ...        1929        408
# 1    CM CAM CDM   71      KAS Eupen 2014 ~ 2019  ...        1906        385
# 2  CAM RM RW LM   71  Coventry City 2016 ~ 2020  ...        1770        354
# 3           NaN   82            Sunderland 2009  ...        1348        369
# 4        CM CAM   81    Vissel Kobe 2018 ~ 2021  ...        2014        420
#
#     IR  PAC SHO PAS DRI DEF PHY Gender
# ...

# %%
#I also drop column 'Team & Contract' because we have it in two other columns 'Club' and 'Contract'
df.drop(['Total Stats', 'Base Stats', 'IR', 'Team & Contract'], axis=1, inplace=True)

# %%
#The remaining 26 colums may be interesting for the data analysis
#We could get rid of ID (not necessary), Position (different positions a player can play), Loan Date End, Joined (already known in Contract)
df
# Out:
#            ID             Name  Age  OVA            Nationality  \
# 0           2      G. Pasquale   33   69                  Italy
# 1          16      Luis García   37   71                  Spain
# 2          27          J. Cole   33   71                England
# 3          36         D. Yorke   36   68  Trinidad &amp; Tobago
# 4          41          Iniesta   36   81                  Spain
# ...       ...              ...  ...  ...                    ...
# 17120  259088       A. Medioub   22   64                 France
# 17121  259090       W. Rickard   18   56                  Wales
# 17122  259091       C. Barrett   18   56                England
# 17123  259101   J. Gazibegović   20   62     Bosnia Herzegovina
# 17124  259105  Pablo Rodríguez   18   59                  Spain
#
#                 Club   BP      Position  POT Height  ...  Wage Release Clause  \
# 0            Udinese  LWB            LM   69   6'0"  ...   €7K             €0
# ...
